# %% [markdown]
# # Deep Embedded Clustering analysis using Pytorch Codes

# %% [markdown]
# The objective of this notebook is to analyse the DEC method using a simple 3D example with a simple Pytorch model.
# Different cases to study:
# - Well separated and balaced datasets.
# - Well separated and imbalanced datasets.
# - Difficult to separate and balanced datasets.
# - Difficult to separate and imbalanced datasets.

# %%
# Import of python packages and modules
import os
import random
import numpy as np
import pandas as pd
import torch
import matplotlib as mpl
import matplotlib.pyplot as plt
from src.experiments.train_single_model import TrainSingleModel
from src.utils.tools import plot_points_by_class_2D, plot_points_by_class_3D, plot_animation, get_mean_metrics

# %%
def change_matplotlib_figures_size():
    #mpl.rcParams['figure.figsize'] = (10, 5) # To increase the size of the plots
    mpl.rcParams['figure.figsize'] = (20, 10) # To increase the size of the plots

    #======================================================================#
    #======================================================================#
    # Defining the plot
    params = {'axes.labelsize': 20,
              'axes.titlesize': 20}
    plt.rcParams.update(params)

change_matplotlib_figures_size()

# %%
# Fixing the random seed
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# %%
# To obtain the animations of the encodings over the epochs 
# (stored in ../../results/Experiment_1/)
obtain_animation_bool = True
#obtain_animation_bool = False

# %% [markdown]
# ## I) Definition of the parameters of the different sub-experiments

# %%
# Parameters of the experiment variable 
sub_exps_params = {
                        'SB No DEC': {},
                        'SB DEC': {},
                        'SI No DEC': {},
                        'SI DEC': {},
                        'NB No DEC': {},
                        'NB DEC': {},
                        'NI No DEC': {},
                        'NI DEC': {},
                    }

# %%
# Dataset to use
sub_exps_params['SB DEC']['dataset_type'] = 'balanced_separated'
sub_exps_params['SB No DEC']['dataset_type'] = 'balanced_separated'
sub_exps_params['SI DEC']['dataset_type'] = 'imbalanced_separated'
sub_exps_params['SI No DEC']['dataset_type'] = 'imbalanced_separated'
sub_exps_params['NB DEC']['dataset_type'] = 'balanced_mixed'
sub_exps_params['NB No DEC']['dataset_type'] = 'balanced_mixed'
sub_exps_params['NI DEC']['dataset_type'] = 'imbalanced_mixed'
sub_exps_params['NI No DEC']['dataset_type'] = 'imbalanced_mixed'

# %%
# Other parameters
nb_repetitions = 10
batch_size = 32
for sub_exp_name in sub_exps_params:
    # Use DEC
    if ('No DEC' in sub_exp_name):
        sub_exps_params[sub_exp_name]['use_dec'] = False
    else:
        sub_exps_params[sub_exp_name]['use_dec'] = True
    # Number of repetitions
    sub_exps_params[sub_exp_name]['nb_repetitions'] = nb_repetitions
    # Batch size
    sub_exps_params[sub_exp_name]['batch_size'] = batch_size

    # DEC hyper-parameters and training parameters
    if ('SB' in sub_exp_name) or ('NI' in sub_exp_name):
        sub_exps_params[sub_exp_name]['importance_dec'] = 1 
        sub_exps_params[sub_exp_name]['epoch_init_dec_loss'] = 5
        sub_exps_params[sub_exp_name]['nb_epochs'] = 50 
        sub_exps_params[sub_exp_name]['lr'] = 5e-2 
    if ('SI' in sub_exp_name):
        sub_exps_params[sub_exp_name]['importance_dec'] = 10 
        sub_exps_params[sub_exp_name]['epoch_init_dec_loss'] = 1 
        sub_exps_params[sub_exp_name]['nb_epochs'] = 50 
        sub_exps_params[sub_exp_name]['lr'] = 5e-3 
    if ('NB' in sub_exp_name):
        sub_exps_params[sub_exp_name]['importance_dec'] = 5e-1 
        sub_exps_params[sub_exp_name]['epoch_init_dec_loss'] = 1 
        sub_exps_params[sub_exp_name]['nb_epochs'] = 100 
        sub_exps_params[sub_exp_name]['lr'] = 1e-2

# %% [markdown]
# ## II) Training of the different models

# %%
metrics_experiment = {sub_exp_name:{} for sub_exp_name in sub_exps_params}
for sub_exp_name in sub_exps_params:
    # Fixing the random seed
    random.seed(42)
    np.random.seed(42)
    torch.manual_seed(42)
    
    # Creation of an instance of the sub-experiment
    single_train_exp = TrainSingleModel(sub_exps_params[sub_exp_name])
    
    # Plotting the generated data
    plot_points_by_class_3D(single_train_exp.X_data, single_train_exp.Y_data, centroids=None, close_fig=False)

    # Training the model
    single_train_exp.repeatedHoldout()

    # Print the mean metrics
    mean_last_mcc, std_last_mcc = get_mean_metrics(single_train_exp.list_last_epoch_metrics, metric_type='MCC')
    mean_last_f1_score, std_last_f1_score = get_mean_metrics(single_train_exp.list_last_epoch_metrics, metric_type='F1-Score')
    mean_last_accuracy, std_last_accuracy = get_mean_metrics(single_train_exp.list_last_epoch_metrics, metric_type='Accuracy')
    
    # Adding the metrics to the dictionary of the metrics of all the experiments 
    metrics_experiment[sub_exp_name]['MCC'] = '{} \u00B1 {}'.format(round(mean_last_mcc, 2), round(std_last_mcc, 2))
    metrics_experiment[sub_exp_name]['F1-Score'] = '{} \u00B1 {}'.format(round(mean_last_f1_score, 2), round(std_last_f1_score, 2))
    metrics_experiment[sub_exp_name]['Accuracy'] = '{} \u00B1 {}'.format(round(mean_last_accuracy, 2), round(std_last_accuracy, 2))
        
    # Getting the encodings and cluster centers for a given repetition
    rep_to_use = 0
    encodings_by_epochs = single_train_exp.list_encodings_by_epochs[rep_to_use]
    cluster_centers_by_epoch = single_train_exp.list_cluster_centers_by_epoch[rep_to_use]
    
    # Plotting the 2D test encodings at the last epoch
    epoch = len(encodings_by_epochs['Test']) - 1
    test_encodings = encodings_by_epochs['Test'][epoch]['Encodings']
    X_data_samples = np.array([ test_encodings[i] for i in range(len(test_encodings)) ])
    Y_data_samples = np.array(encodings_by_epochs['Test'][epoch]['TrueLabels'])
    if (epoch not in cluster_centers_by_epoch):
        plot_points_by_class_2D(X_data_samples, Y_data_samples, centroids=None, show_fig=True, save_fig=False)
    else:
        plot_points_by_class_2D(X_data_samples, Y_data_samples, centroids=cluster_centers_by_epoch[epoch], show_fig=True, save_fig=False)
        
    # Plotting the animation with the original labels
    if (obtain_animation_bool):
        for epoch in range(single_train_exp.nb_epochs):
            test_encodings = encodings_by_epochs['Test'][epoch]['Encodings']
            X_data_samples = np.array([test_encodings[i] for i in range(len(test_encodings)) ])
            Y_data_samples = np.array(encodings_by_epochs['Test'][epoch]['TrueLabels'])
            if (epoch not in cluster_centers_by_epoch):
                plot_points_by_class_2D(X_data_samples, Y_data_samples, centroids=None, show_fig=False, save_fig=True, file_name_fig='tmp_img_{}_epoch-{}.png'.format(sub_exp_name, epoch))
            else:
                plot_points_by_class_2D(X_data_samples, Y_data_samples, centroids=cluster_centers_by_epoch[epoch], show_fig=False, save_fig=True, file_name_fig='tmp_img_{}_epoch-{}.png'.format(sub_exp_name, epoch))

        # Plotting the animation
        files_image_list = ['../../results/.tmp_images_for_gif/tmp_img_{}_epoch-{}.png'.format(sub_exp_name, i) for i in range(single_train_exp.nb_epochs)]
        if (not os.path.isdir('../../results/Experiment_1/')):
            os.mkdir('../../results/Experiment_1/')
        animation_file_name = '../../results/Experiment_1/TestEmbeddings_{}.mp4'.format(sub_exp_name)
        plot_animation(files_image_list, animation_file_name)
    
    # Erasing all the images in the tmpImagesForGIF folder
    for file in os.listdir("../../results/.tmp_images_for_gif/"):
        os.remove("../../results/.tmp_images_for_gif/"+file)
# Out:
# =======> Doing repetition 0
# =======> Doing repetition 1
# =======> Doing repetition 2
# =======> Doing repetition 3
# =======> Doing repetition 4
# =======> Doing repetition 5
# =======> Doing repetition 6
# =======> Doing repetition 7
# =======> Doing repetition 8
# =======> Doing repetition 9
# 	Test MCC: 99.89997746736175 +- 0.20004509088906697
# 	Test F1-Score: 99.93333333333332 +- 0.13333333333333197
# 	Test Accuracy: 99.93333333333332 +- 0.13333333333333197
# =======> Doing repetition 0
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 1
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 2
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 3
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 4
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 5
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 6
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 7
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 8
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 9
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 	Test MCC: 99.7999367891746 +- 0.2450274648493734
# 	Test F1-Score: 99.86666666666666 +- 0.16329931618554352
# 	Test Accuracy: 99.86666666666666 +- 0.16329931618554352
# =======> Doing repetition 0
# =======> Doing repetition 1
# =======> Doing repetition 2
# =======> Doing repetition 3
# =======> Doing repetition 4
# =======> Doing repetition 5
# =======> Doing repetition 6
# =======> Doing repetition 7
# =======> Doing repetition 8
# =======> Doing repetition 9
# 	Test MCC: 88.00558999937108 +- 3.633160676455299
# 	Test F1-Score: 94.82692307692308 +- 1.650264457917304
# 	Test Accuracy: 94.82692307692308 +- 1.650264457917304
# =======> Doing repetition 0
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 1
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 2
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 3
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 4
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 5
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 6
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 7
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 8
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 9
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 	Test MCC: 93.40094483853282 +- 3.660629470710525
# 	Test F1-Score: 97.33653846153845 +- 1.6301125764297142
# 	Test Accuracy: 97.33653846153845 +- 1.6301125764297142
# =======> Doing repetition 0
# =======> Doing repetition 1
# =======> Doing repetition 2
# =======> Doing repetition 3
# =======> Doing repetition 4
# =======> Doing repetition 5
# =======> Doing repetition 6
# =======> Doing repetition 7
# =======> Doing repetition 8
# =======> Doing repetition 9
# 	Test MCC: 96.80138734211727 +- 0.8684904737510617
# 	Test F1-Score: 97.86666666666666 +- 0.5811865258054226
# 	Test Accuracy: 97.86666666666666 +- 0.5811865258054211
# =======> Doing repetition 0
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 1
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 2
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 3
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 4
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 5
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 6
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 7
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 8
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 9
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 	Test MCC: 96.49974475698828 +- 0.9824013556654545
# 	Test F1-Score: 97.66666666666666 +- 0.6497862896539299
# 	Test Accuracy: 97.66666666666666 +- 0.6497862896539299
# =======> Doing repetition 0
# =======> Doing repetition 1
# =======> Doing repetition 2
# =======> Doing repetition 3
# =======> Doing repetition 4
# =======> Doing repetition 5
# =======> Doing repetition 6
# =======> Doing repetition 7
# =======> Doing repetition 8
# =======> Doing repetition 9
# 	Test MCC: 88.76240077858654 +- 3.5539651435239183
# 	Test F1-Score: 95.27884615384615 +- 1.6545447987661923
# 	Test Accuracy: 95.27884615384615 +- 1.6545447987661914
# =======> Doing repetition 0
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 1
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 2
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 3
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 4
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 5
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 6
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 7
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 8
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# =======> Doing repetition 9
# /home/vindas/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 	Test MCC: 94.10631071353176 +- 1.3405651605286195
# 	Test F1-Score: 97.8076923076923 +- 0.4381071442267125
# 	Test Accuracy: 97.8076923076923 +- 0.4381071442267125

# %%
# Plotting the results in a table format
results_df = pd.DataFrame(metrics_experiment).T
print(results_df)
# Out:
#                     MCC      F1-Score      Accuracy
# SB No DEC    99.9 ± 0.2  99.93 ± 0.13  99.93 ± 0.13
# SB DEC      99.8 ± 0.25  99.87 ± 0.16  99.87 ± 0.16
# SI No DEC  88.01 ± 3.63  94.83 ± 1.65  94.83 ± 1.65
# SI DEC      93.4 ± 3.66  97.34 ± 1.63  97.34 ± 1.63
# NB No DEC   96.8 ± 0.87  97.87 ± 0.58  97.87 ± 0.58
# NB DEC      96.5 ± 0.98  97.67 ± 0.65  97.67 ± 0.65
# NI No DEC  88.76 ± 3.55  95.28 ± 1.65  95.28 ± 1.65
# NI DEC     94.11 ± 1.34  97.81 ± 0.44  97.81 ± 0.44
